# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratchadakorn26/BSC_DPDM23/blob/main/Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##Load data

# %% [markdown]
# ##แบบ load Excel from Google dive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_from_gdive= pd.read_excel("/content/drive/MyDrive/data mining/2563.xls",header=2)

# %%
data_from_gdive
# Out:
#     เลขที่คำขอ เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย  \
# 0       610707   62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 1       620660   63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 2       610182   63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 3       620318   63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# 4       620185   63-0079-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# ..         ...                ...                                      ...
# 655    E630369   63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 656    E630401   63-0682-1-00-1-0                            โกลว์ พลังงาน
# 657    E630277   63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 658     610552   63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 659    E630269   63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %% [markdown]
# #แบบ gsheet

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds,_= default()
gc=gspread.authorize(creds)

# %%
gsht=gc.open_by_key('1wyPESk_ci2K69lF0CkGl5OpwBcDi1x6byfGHyGtcVYk')

# %%
worksheet2=gsht.worksheet("มิ.ย. 2563")
rows = worksheet2.get_all_values()
data_from_gsheets= pd.DataFrame.from_records(rows)

# %%
data_from_gsheets
# Out:
#             0                   1                                        2    \
# 0
# 1
# 2    เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 3        610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 4        620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# ..          ...                 ...                                      ...
# 658     E630369    63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 659     E630401    63-0682-1-00-1-0                            โกลว์ พลังงาน
# 660     E630277    63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 661      610552    63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 662     E630269    63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
#                                                    3              4    \
# 0
# 1
# 2                                    สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์
# ...

# %%
data_from_gsheets.columns = data_from_gsheets.iloc[2]
data_from_gsheets= data_from_gsheets.iloc[2:].reset_index()
data_from_gsheets.head()
# Out:
# 2  index  เลขที่คำขอ  เลขที่บัตรส่งเสริม  \
# 0      2  เลขที่คำขอ  เลขที่บัตรส่งเสริม
# 1      3      610707    62-0422-1-04-1-0
# 2      4      620660    63-0107-1-00-1-0
# 3      5      610182    63-0101-1-00-1-0
# 4      6      620318    63-0080-1-00-0-0
#
# 2                        ชื่อบริษัทภาษาไทย  \
# 0                        ชื่อบริษัทภาษาไทย
# 1  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 2                        เจ้าพระยา คาร์บอน
# 3                        อาร์ต ออฟ เบคกิ้ง
# 4       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
#
# 2                                  สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์  \
# 0                                  สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์
# 1  46/1,46/2 หมู่ที่ 12 ถนนบางพลี-บางนาตราด ต.บาง...  02-3373078-84
# 2          ต.เขาล้าน อ.ทับสะแก ประจวบคีรีขันธ์ 77130    081-8412110
# 3  111/21 หมู่ที่ 2 ต.ท่าจีน อ.เมือง สมุทรสาคร 74000     034-440157
# 4   700/864 หมู่ที่ 1 ต.พานทอง อ.พานทอง ชลบุรี 20160
#
# ...

# %% [markdown]
# ##Basic stats

# %%
data_from_gdive.describe()
# Out:
#         อุตสาหการ       ไฟฟ้า  อิเล็กทรอนิกส์และโทรคมนาคม   เครื่องกล  \
# count  660.000000  660.000000                  660.000000  660.000000
# mean     0.766667    0.933333                    0.568182    0.966667
# std      2.666053    2.102483                    3.711511    3.491865
# min      0.000000    0.000000                    0.000000    0.000000
# 25%      0.000000    0.000000                    0.000000    0.000000
# 50%      0.000000    0.000000                    0.000000    0.000000
# 75%      0.000000    1.000000                    0.000000    1.000000
# max     30.000000   23.000000                   69.000000   71.000000
#
#         วิศวะเคมี   ปิโตรเคมี        โยธา  คอมพิวเตอร์       สำรวจ  \
# count  660.000000  660.000000  660.000000   660.000000  660.000000
# mean     0.128788    0.010606    0.022727     0.827273    0.007576
# std      0.590842    0.116380    0.235857     3.343353    0.116617
# ...

# %%
data_from_gsheets.describe()
# Out:
# 2           index
# count  661.000000
# mean   332.000000
# std    190.958547
# min      2.000000
# 25%    167.000000
# 50%    332.000000
# 75%    497.000000
# max    662.000000

# %% [markdown]
# ##VisualiZation

# %% [markdown]
# ##Distance-Similarity

# %% [markdown]
# Z-score
